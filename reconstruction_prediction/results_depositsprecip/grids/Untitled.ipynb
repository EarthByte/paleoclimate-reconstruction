# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
names=["lat","lon","precip_actual","precip_mean","precip_low","precip_high","coal_mean","evap_mean",
 "glacial_mean","coal_low","evap_low","glacial_low","coal_high","evap_high","glacial_high",
 "coal_actual","evap_actual","glacial_actual","1","2","3","4","5","6"]

# %%
df=pd.read_csv("../era51results.csv",names=names)
for n in names[2:-6]:
    print(n)
    df2=pd.read_csv("51Ma_"+n+".xyz",names=["lon","lat",n],sep='\s+')
    df3=pd.read_csv("51Ma_"+n+".block",names=["lon","lat",n],sep='\s+')

    plt.scatter(df.lon,df.lat,c=df[n],s=20)
    plt.show()
    plt.scatter(df2.lon,df2.lat,c=df2[n],s=20)
    plt.show()
    plt.scatter(df3.lon,df3.lat,c=df3[n],s=20)
    plt.show()
# Out:
# precip_actual
# precip_mean
# precip_low
# precip_high
# coal_mean
# evap_mean
# glacial_mean
# coal_low
# evap_low
# glacial_low
# coal_high
# evap_high
# glacial_high
# coal_actual
# evap_actual
# glacial_actual

# %%
df3[n].describe()
# Out:
# count    1294.000000
# mean     -947.274343
# std       216.149798
# min      -999.000000
# 25%      -999.000000
# 50%      -999.000000
# 75%      -999.000000
# max         0.000000
# Name: glacial_actual, dtype: float64

# %%
df
# Out:
#         lat     lon  2precip_actual  3precip_mean  4precip_low  5precip_high  \
# 0    -69.02  -68.31            1.14       0.92828      0.73113       1.15830
# 1    -69.02  -60.78            0.47       0.78901      0.63251       0.99616
# 2    -69.02   34.60            0.57       0.73844      0.57819       0.94544
# 3    -69.02   42.13            0.52       0.86442      0.69175       1.07630
# 4    -69.02   44.64            0.62       0.84042      0.67489       1.04260
# ...     ...     ...             ...           ...          ...           ...
# 1758  69.02  167.63            0.73       0.72876      0.59405       0.80856
# 1759  69.02  170.14            0.69       0.73572      0.58981       0.81941
# 1760  69.02  172.65            0.60       0.97905      0.82799       1.07390
# 1761  69.02  175.16            0.69       0.90602      0.75638       1.00190
# 1762  69.02  177.67            0.73       1.02900      0.89357       1.12100
#
#       6coal_mean  7evap_mean  8glacial_mean  9coal_low  ...  14glacial_high  \
# 0        0.55478    0.011043       0.753240   0.156780  ...        0.999980
# 1        0.38983    0.028223       0.570410   0.070060  ...        0.982470
# 2        0.24895    0.059660       0.797840   0.001989  ...        1.000000
# 3        0.32590    0.025793       0.805560   0.007891  ...        1.000000
# 4        0.35644    0.020804       0.792680   0.010690  ...        1.000000
# ...          ...         ...            ...        ...  ...             ...
# 1758     0.85662    0.016799       0.092570   0.582370  ...        0.454110
# 1759     0.91473    0.008333       0.150240   0.710830  ...        0.709910
# 1760     0.85290    0.019180       0.018917   0.584850  ...        0.091892
# 1761     0.83130    0.023440       0.034610   0.537900  ...        0.178760
# 1762     0.91531    0.010212       0.018133   0.719440  ...        0.098006
#
#       15coal_actual  16evap_actual  17glacial_actual      1      2     3  \
# 0            -999.0         -999.0            -999.0  31.95   6.90 -1.00
# 1               0.0            0.0               1.0   0.00   0.00  0.94
# 2            -999.0         -999.0            -999.0   8.38   6.64 -1.00
# 3            -999.0         -999.0            -999.0  28.94   8.07 -1.00
# 4            -999.0         -999.0            -999.0  39.32  11.96 -0.62
# ...             ...            ...               ...    ...    ...   ...
# 1758         -999.0         -999.0            -999.0  18.61  14.07  0.54
# 1759         -999.0         -999.0            -999.0  29.14  12.85  0.08
# 1760         -999.0         -999.0            -999.0  16.91  11.22  0.45
# 1761         -999.0         -999.0            -999.0  10.67  10.66 -0.06
# 1762         -999.0         -999.0            -999.0  22.71   7.69  0.22
#
#          4        5     6
# 0     0.04  1021.05  14.0
# 1     0.34     0.00  14.0
# 2     0.04    70.15  14.0
# 3     0.02   837.38  14.0
# 4     0.78  1546.20  14.0
# ...    ...      ...   ...
# 1758  0.84   346.28  14.0
# 1759  1.00   849.14  14.0
# 1760 -0.90   285.86  14.0
# 1761 -1.00   113.87  14.0
# 1762 -0.97   515.92  14.0
#
# [1763 rows x 24 columns]
